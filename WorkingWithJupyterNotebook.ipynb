# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets
#   Downloading ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 9.1 MB/s
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 15.0 MB/s
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.0.7-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 74.0 MB/s
# Requirement already satisfied: ipykernel>=4.5.1 in /home/codespace/.local/lib/python3.5/site-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/codespace/.local/lib/python3.5/site-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.5/site-packages (from ipywidgets) (4.3.3)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.1.3-py3-none-any.whl (9.4 MB)
#      |████████████████████████████████| 9.4 MB 67.9 MB/s
# Requirement already satisfied: jupyter-core in /home/codespace/.local/lib/python3.5/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.3)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.4 MB/s
# Requirement already satisfied: ipython-genutils in /home/codespace/.local/lib/python3.5/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /home/codespace/.local/lib/python3.5/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /home/codespace/.local/lib/python3.5/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.6)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (33.1.1)
# Requirement already satisfied: pygments in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.6.1)
# Requirement already satisfied: pickleshare in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.17.2)
# Requirement already satisfied: backcall in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.0.10)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/codespace/.local/lib/python3.5/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.5/site-packages (from traitlets>=4.3.1->ipywidgets) (1.15.0)
# Collecting jinja2
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 76.3 MB/s
# Collecting prometheus-client
#   Downloading prometheus_client-0.8.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.9 MB/s
# Collecting Send2Trash
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.8.3-py2.py3-none-any.whl (33 kB)
# Collecting nbconvert
#   Downloading nbconvert-5.6.1-py2.py3-none-any.whl (455 kB)
#      |████████████████████████████████| 455 kB 53.9 MB/s
# Requirement already satisfied: pyzmq>=17 in /home/codespace/.local/lib/python3.5/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (19.0.2)
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.1 MB/s
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.16.0.tar.gz (108 kB)
#      |████████████████████████████████| 108 kB 101.7 MB/s
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /home/codespace/.local/lib/python3.5/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/codespace/.local/lib/python3.5/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.1)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.5/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.5/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp35-cp35m-manylinux1_x86_64.whl (27 kB)
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting bleach
#   Downloading bleach-3.1.5-py2.py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 87.0 MB/s
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 95.4 MB/s
# Collecting defusedxml
#   Downloading defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.2.tar.gz (14 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting cffi>=1.0.0
#   Downloading cffi-1.14.2-cp35-cp35m-manylinux1_x86_64.whl (400 kB)
#      |████████████████████████████████| 400 kB 68.2 MB/s
# Collecting zipp>=0.5
#   Downloading zipp-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting packaging
#   Downloading packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 44.3 MB/s
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.9 MB/s
# Using legacy 'setup.py install' for pyrsistent, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for pandocfilters, since package 'wheel' is not installed.
# Installing collected packages: MarkupSafe, jinja2, prometheus-client, Send2Trash, terminado, entrypoints, pyparsing, packaging, webencodings, bleach, testpath, defusedxml, pyrsistent, zipp, importlib-metadata, attrs, jsonschema, nbformat, pandocfilters, mistune, nbconvert, pycparser, cffi, argon2-cffi, notebook, widgetsnbextension, ipywidgets
#     Running setup.py install for pyrsistent ... done
#     Running setup.py install for pandocfilters ... done
# Successfully installed MarkupSafe-1.1.1 Send2Trash-1.5.0 argon2-cffi-20.1.0 attrs-19.3.0 bleach-3.1.5 cffi-1.14.2 defusedxml-0.6.0 entrypoints-0.3 importlib-metadata-1.7.0 ipywidgets-7.5.1 jinja2-2.11.2 jsonschema-3.2.0 mistune-0.8.4 nbconvert-5.6.1 nbformat-5.0.7 notebook-6.1.3 packaging-20.4 pandocfilters-1.4.2 prometheus-client-0.8.0 pycparser-2.20 pyparsing-2.4.7 pyrsistent-0.16.0 terminado-0.8.3 testpath-0.4.4 webencodings-0.5.1 widgetsnbextension-3.5.1 zipp-1.2.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
@interact
def show_articles_more_than(column = 'petal_length', x=5):
    
    return iris.loc[iris[column] > x]
# Out:
# interactive(children=(Text(value='petal_length', description='column'), IntSlider(value=5, description='x', ma…

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
iris.duplicated().sum()
# Out:
# 3

# %%
iris.drop_duplicates(keep=False, 
                     inplace=True)

# %%
iris.duplicated().sum()
# Out:
# 0

# %%
x = iris.iloc[:, :4]
y = iris['species']

# %%
x.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
plt.figure(figsize = (8, 6)) 

plt.hist(iris['sepal_length'],
         bins = 20, color = "g")

plt.xlabel("Sepal Length") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (8, 6)) 

plt.hist(iris['sepal_width'],
         bins = 20, color = "b")

plt.xlabel("Sepal Width") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
fig, ax = plt.subplots(1, 2,
                       figsize = (15, 6))

iris.plot(x = "sepal_length", y = "sepal_width",
          kind = "scatter", ax = ax[0],
          sharex  =False, sharey = False,
          label = "sepal", color = 'r')


iris.plot(x = "petal_length", y = "petal_width",
          kind = "scatter", ax = ax[1],
          sharex = False, sharey = False,
          label = "petal", color = 'b')

# %%
def plot(species):
    data = iris[iris.species == species]
    
    data.plot.scatter('sepal_length',
                      'sepal_width')
    
interact(plot, kind = 'scatter',
         species = 'Iris-virginica')
# Out:
# interactive(children=(Text(value='Iris-virginica', description='species'), Output()), _dom_classes=('widget-in…
# <function __main__.plot(species)>

# %%
iris.to_csv('saved_iris_df.csv', index = False)
